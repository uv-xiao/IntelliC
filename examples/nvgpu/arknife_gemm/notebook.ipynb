# %% [markdown]
# # HTP NV-GPU Example\n\nThis notebook wraps the runnable `examples.nvgpu_arknife_gemm.demo` module.\nThe real example logic lives in Python so it remains testable and diffable.

# %%
from pathlib import Path\nfrom examples.nvgpu_arknife_gemm.demo import run_demo\n\nsummary = run_demo(Path("artifacts") / "nvgpu_arknife_gemm")\nsummary
