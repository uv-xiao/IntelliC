# %% [markdown]
# # HTP PTO Example\n\nThis notebook wraps the runnable `examples.pto_pypto_vector_add.demo` module.\nIt is intentionally thin: the real example logic lives in Python files so it stays testable.

# %%
from pathlib import Path\nfrom examples.pto_pypto_vector_add.demo import run_demo\n\nsummary = run_demo(Path("artifacts") / "pto_pypto_vector_add")\nsummary
